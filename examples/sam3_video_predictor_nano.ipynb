# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.

# %%
# !nvidia-smi
# Out:
# Wed May 20 19:40:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        On  |   00000000:B8:00.0 Off |                  N/A |
# |  0%   30C    P8             21W /  600W |       0MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sam3

# Redirect Triton/PyTorch caches away from home directory quota limits.
runtime_cache_root = os.path.abspath("./.runtime_cache")
triton_cache_dir = os.path.join(runtime_cache_root, "triton")
torchinductor_cache_dir = os.path.join(runtime_cache_root, "torchinductor")
xdg_cache_home = os.path.join(runtime_cache_root, "xdg")

for cache_dir in (runtime_cache_root, triton_cache_dir, torchinductor_cache_dir, xdg_cache_home):
    os.makedirs(cache_dir, exist_ok=True)

os.environ.setdefault("TRITON_CACHE_DIR", triton_cache_dir)
os.environ.setdefault("TORCHINDUCTOR_CACHE_DIR", torchinductor_cache_dir)
os.environ.setdefault("XDG_CACHE_HOME", xdg_cache_home)

import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]

print("TRITON_CACHE_DIR:", os.environ["TRITON_CACHE_DIR"])
print("TORCHINDUCTOR_CACHE_DIR:", os.environ["TORCHINDUCTOR_CACHE_DIR"])
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
# /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor
ckpt = "/data/home/scvi576/run/JiaBSH/sam3/ms_cache/facebook/sam3/sam3.pt" # <-- change to your local file


predictor = build_sam3_video_predictor(checkpoint_path=ckpt,gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-05-20 19:48:38,638 1279217 sam3_video_predictor.py: 109: using the following GPU IDs: [0]
# INFO 2026-05-20 19:48:38,638 1279217 sam3_video_predictor.py: 125:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-05-20 19:48:38,639 1279217 sam3_video_predictor.py: 127: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-05-20 19:48:43,102 1279217 sam3_video_base.py: 348: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-05-20 19:48:48,040 1279217 sam3_video_predictor.py: 129: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-05-20 19:48:48,041 1279217 sam3_video_predictor.py: 140:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 270/270 [00:22<00:00, 11.76it/s]
# INFO 2026-05-20 19:51:18,206 1279217 sam3_base_predictor.py: 146: started new session c28aad65-3212-4151-a649-daa1671fd05f

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 3
#       1 prompt_text_str = "person"
#       2 frame_idx = 0  # add a text prompt on frame 0
# ----> 3 response = predictor.handle_request(
#       4     request=dict(
#       5         type="add_prompt",
#       6         session_id=session_id,
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_predictor.py:159, in Sam3VideoPredictorMultiGPU.handle_request(self, request)
#     156     for rank in range(1, self.world_size):
#     157         self.command_queues[rank].put((request, False))
# --> 159 response = super().handle_request(request)
#     161 if self.world_size > 1:
#     162     torch.distributed.barrier()  # wait for all ranks to finish
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_base_predictor.py:61, in Sam3BasePredictor.handle_request(self, request)
#      54     return self.start_session(
#      55         resource_path=request["resource_path"],
#      56         session_id=request.get("session_id", None),
#      57         offload_video_to_cpu=request.get("offload_video_to_cpu", False),
#      58         offload_state_to_cpu=request.get("offload_state_to_cpu", False),
#      59     )
#      60 elif request_type == "add_prompt":
# ---> 61     return self.add_prompt(
#      62         session_id=request["session_id"],
#      63         frame_idx=request["frame_index"],
#      64         text=request.get("text", None),
#      65         points=request.get("points", None),
#      66         point_labels=request.get("point_labels", None),
#      67         clear_old_points=request.get("clear_old_points", True),
#      68         bounding_boxes=request.get("bounding_boxes", None),
#      69         bounding_box_labels=request.get("bounding_box_labels", None),
#      70         clear_old_boxes=request.get("clear_old_boxes", True),
#      71         output_prob_thresh=request.get(
#      72             "output_prob_thresh",
#      73             getattr(self, "default_output_prob_thresh", 0.5),
#      74         ),
#      75         obj_id=request.get("obj_id", None),
#      76         rel_coordinates=request.get("rel_coordinates", True),
#      77     )
#      78 elif request_type == "remove_object":
#      79     return self.remove_object(
#      80         session_id=request["session_id"],
#      81         frame_idx=request.get("frame_index", 0),
#      82         obj_id=request["obj_id"],
#      83     )
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_base_predictor.py:206, in Sam3BasePredictor.add_prompt(self, session_id, frame_idx, text, points, point_labels, clear_old_points, bounding_boxes, bounding_box_labels, clear_old_boxes, output_prob_thresh, obj_id, rel_coordinates)
#     203 filtered_kwargs = {k: v for k, v in kwargs.items() if k in valid_params}
#     205 with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
# --> 206     frame_idx, outputs = self.model.add_prompt(**filtered_kwargs)
#     207 return {"frame_index": frame_idx, "outputs": outputs}
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_inference.py:1391, in Sam3VideoInferenceWithInstanceInteractivity.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels, points, point_labels, obj_id, rel_coordinates)
#    1380     return self.add_tracker_new_points(
#    1381         inference_state,
#    1382         frame_idx,
#    (...)   1387         use_prev_mem_frame=self.use_prev_mem_frame,
#    1388     )
#    1389 else:
#    1390     # SAM3 prompts
# -> 1391     return super().add_prompt(
#    1392         inference_state,
#    1393         frame_idx,
#    1394         text_str=text_str,
#    1395         boxes_xywh=boxes_xywh,
#    1396         box_labels=box_labels,
#    1397     )
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_inference.py:903, in Sam3VideoInference.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels)
#     897     boxes_cxcywh, box_labels, geometric_prompt = self._get_visual_prompt(
#     898         inference_state, frame_idx, boxes_cxcywh, box_labels
#     899     )
#     901     inference_state["per_frame_geometric_prompt"][frame_idx] = geometric_prompt
# --> 903 out = self._run_single_frame_inference(
#     904     inference_state, frame_idx, reverse=False
#     905 )
#     906 return frame_idx, self._postprocess_output(inference_state, out)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_inference.py:380, in Sam3VideoInference._run_single_frame_inference(self, inference_state, frame_idx, reverse)
#     369 has_geometric_prompt = (
#     370     inference_state["per_frame_geometric_prompt"][frame_idx] is not None
#     371 )
#     372 # run inference for the current frame
#     373 (
#     374     obj_id_to_mask,
#     375     obj_id_to_score,
#     376     tracker_states_local_new,
#     377     tracker_metadata_new,
#     378     frame_stats,
#     379     _,
# --> 380 ) = self._det_track_one_frame(
#     381     frame_idx=frame_idx,
#     382     num_frames=inference_state["num_frames"],
#     383     reverse=reverse,
#     384     input_batch=input_batch,
#     385     geometric_prompt=(
#     386         inference_state["constants"]["empty_geometric_prompt"]
#     387         if not has_geometric_prompt
#     388         else inference_state["per_frame_geometric_prompt"][frame_idx]
#     389     ),
#     390     tracker_states_local=tracker_states_local,
#     391     tracker_metadata_prev=inference_state["tracker_metadata"],
#     392     feature_cache=inference_state["feature_cache"],
#     393     orig_vid_height=inference_state["orig_height"],
#     394     orig_vid_width=inference_state["orig_width"],
#     395     is_image_only=inference_state["is_image_only"],
#     396     allow_new_detections=has_text_prompt or has_geometric_prompt,
#     397 )
#     398 # update inference state
#     399 inference_state["tracker_inference_states"] = tracker_states_local_new
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_base.py:407, in Sam3VideoBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only, allow_new_detections)
#     390 """
#     391 This function handles one-step inference for the DenseTracking model in an SPMD manner.
#     392 At a high-level, all GPUs execute the same function calls as if it's done on a single GPU,
#    (...)    399   it contains both global and local masklet information
#     400 """
#     402 # Step 1: run backbone and detector in a distributed manner -- this is done via Sam3ImageOnVideoMultiGPU,
#     403 # a MultiGPU model (assigned to `self.detector`) that shards frames in a round-robin manner.
#     404 # It returns a "det_out" dict for `frame_idx` and fills SAM2 backbone features for `frame_idx`
#     405 # into `feature_cache`. Despite its distributed inference under the hood, the results would be
#     406 # the same as if it is running backbone and detector for every frame on a single GPU.
# --> 407 det_out = self.run_backbone_and_detection(
#     408     frame_idx=frame_idx,
#     409     num_frames=num_frames,
#     410     reverse=reverse,
#     411     input_batch=input_batch,
#     412     geometric_prompt=geometric_prompt,
#     413     feature_cache=feature_cache,
#     414     allow_new_detections=allow_new_detections,
#     415 )
#     417 # Step 2: each GPU propagates its local SAM2 states to get the SAM2 prediction masks.
#     418 # the returned `tracker_low_res_masks_global` contains the concatenated masklet predictions
#     419 # gathered from all GPUs (as if they are propagated on a single GPU). Note that this step only
#     420 # runs the SAM2 propagation step, but doesn't encode new memory for the predicted masks;
#     421 # we defer memory encoding to `run_tracker_update_execution_phase` after resolving all heuristics.
#     422 if tracker_metadata_prev == {}:
#     423     # initialize masklet metadata if it's uninitialized (empty dict)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_video_base.py:568, in Sam3VideoBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, allow_new_detections)
#     565 max_frame_num_to_track = tracking_bounds.get("max_frame_num_to_track")
#     566 start_frame_idx = tracking_bounds.get("propagate_in_video_start_frame_idx")
# --> 568 sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     569     backbone_out={
#     570         "img_batch_all_stages": input_batch.img_batch,
#     571         **text_outputs,
#     572     },
#     573     find_inputs=input_batch.find_inputs,
#     574     geometric_prompt=geometric_prompt,
#     575     frame_idx=frame_idx,
#     576     num_frames=num_frames,
#     577     multigpu_buffer=feature_cache["multigpu_buffer"],
#     578     track_in_reverse=reverse,
#     579     # also get the SAM2 backbone features
#     580     return_tracker_backbone_feats=True,
#     581     # run NMS as a part of distributed computation
#     582     run_nms=self.det_nms_thresh > 0.0,
#     583     nms_prob_thresh=self.score_threshold_detection,
#     584     nms_iou_thresh=self.det_nms_thresh,
#     585     # pass max_frame_num_to_track to respect tracking limits
#     586     max_frame_num_to_track=max_frame_num_to_track,
#     587     propagate_in_video_start_frame_idx=start_frame_idx,
#     588 )
#     589 # note: detections in `sam3_image_out` has already gone through NMS
#     590 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_image.py:755, in Sam3ImageOnVideoMultiGPU.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, **kwargs)
#     753 if frame_idx not in multigpu_buffer:
#     754     with torch.profiler.record_function("build_multigpu_buffer_next_chunk1"):
# --> 755         self._build_multigpu_buffer_next_chunk(
#     756             backbone_out=backbone_out,
#     757             find_inputs=find_inputs,
#     758             geometric_prompt=geometric_prompt,
#     759             frame_idx_begin=frame_idx_curr_b,
#     760             frame_idx_end=frame_idx_curr_e,
#     761             num_frames=num_frames,
#     762             multigpu_buffer=multigpu_buffer,
#     763             run_nms=run_nms,
#     764             nms_prob_thresh=nms_prob_thresh,
#     765             nms_iou_thresh=nms_iou_thresh,
#     766         )
#     768 # read out the current frame's results from `multigpu_buffer`
#     769 out = {}
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/model/sam3_image.py:849, in Sam3ImageOnVideoMultiGPU._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh)
#     847 # loop over text prompts (not an overhead for demo where there's only 1 prompt)
#     848 for prompt_idx in range(pred_probs.size(0)):
# --> 849     keep = nms_masks(
#     850         pred_probs=pred_probs[prompt_idx],
#     851         pred_masks=pred_masks[prompt_idx],
#     852         prob_threshold=nms_prob_thresh,
#     853         iou_threshold=nms_iou_thresh,
#     854     )
#     855     # set a very low threshold for those detections removed by NMS
#     856     out_local["pred_logits"][prompt_idx, :, 0] -= 1e4 * (~keep).float()
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/perflib/nms.py:48, in nms_masks(pred_probs, pred_masks, prob_threshold, iou_threshold)
#      45     return is_valid  # no valid detection, return empty keep mask
#      47 ious = mask_iou(masks_binary, masks_binary)  # (num_valid, num_valid)
# ---> 48 kept_inds = generic_nms(ious, probs, iou_threshold)
#      50 # valid_inds are the indices among `probs` of valid detections before NMS (or -1 for invalid)
#      51 valid_inds = torch.where(is_valid, is_valid.cumsum(dim=0) - 1, -1)  # (num_det,)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/perflib/nms.py:70, in generic_nms(ious, scores, iou_threshold)
#      67     else:
#      68         from sam3.perflib.triton.nms import nms_triton
# ---> 70         return nms_triton(ious, scores, iou_threshold)
#      72 return generic_nms_cpu(ious, scores, iou_threshold)
#
# File /data/run01/scvi576/JiaBSH/sam3/sam3/perflib/triton/nms.py:116, in nms_triton(ious, scores, iou_threshold)
#     113 # For the suppression stage, we need to process sequentially, but we'll still take
#     114 # advantage of parallelism by processing in blocks in one program.
#     115 stage2_grid = (1,)
# --> 116 _nms_suppression_kernel[stage2_grid](
#     117     # Tensors
#     118     iou_mask_ptr=iou_mask,
#     119     keep_mask_ptr=keep_mask,
#     120     # Scalars
#     121     num_boxes=num_boxes,
#     122     # Strides
#     123     iou_mask_stride=iou_mask.stride(0),
#     124 )
#     125 # Extract indices of kept boxes
#     126 return sorted_indices[keep_mask]
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/jit.py:370, in KernelInterface.__getitem__.<locals>.<lambda>(*args, **kwargs)
#     364 def __getitem__(self, grid) -> T:
#     365     """
#     366     A JIT function is launched with: fn[grid](*args, **kwargs).
#     367     Hence JITFunction.__getitem__ returns a callable proxy that
#     368     memorizes the grid.
#     369     """
# --> 370     return lambda *args, **kwargs: self.run(grid=grid, warmup=False, *args, **kwargs)
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/autotuner.py:240, in Autotuner.run(self, *args, **kwargs)
#     238             used_cached_result = self.check_disk_cache(key, pruned_configs, benchmark)
#     239         else:
# --> 240             benchmark()
#     242     config = self.cache[key]
#     243 else:
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/autotuner.py:229, in Autotuner.run.<locals>.benchmark()
#     227 def benchmark():
#     228     bench_start = time.time()
# --> 229     timings = {config: self._bench(*args, config=config, **kwargs) for config in pruned_configs}
#     230     bench_end = time.time()
#     231     self.bench_time = bench_end - bench_start
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/autotuner.py:164, in Autotuner._bench(self, config, *args, **meta)
#     161     self.post_hook(full_nargs, exception=None)
#     163 try:
# --> 164     return self.do_bench(kernel_call, quantiles=(0.5, 0.2, 0.8))
#     165 except (OutOfResources, CompileTimeAssertionFailure, PTXASError) as e:
#     166     if verbose:
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/functools.py:998, in cached_property.__get__(self, instance, owner)
#     996 val = cache.get(self.attrname, _NOT_FOUND)
#     997 if val is _NOT_FOUND:
# --> 998     val = self.func(instance)
#     999     try:
#    1000         cache[self.attrname] = val
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/autotuner.py:125, in Autotuner.do_bench(self)
#     122 @cached_property
#     123 def do_bench(self):
#     124     if self._do_bench is None:
# --> 125         return driver.active.get_benchmarker()
#     126     return self._do_bench
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/driver.py:28, in DriverConfig.active(self)
#      25 @property
#      26 def active(self) -> DriverBase:
#      27     if self._active is None:
# ---> 28         self._active = self.default
#      29     return self._active
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/driver.py:22, in DriverConfig.default(self)
#      19 @property
#      20 def default(self) -> DriverBase:
#      21     if self._default is None:
# ---> 22         self._default = _create_driver()
#      23     return self._default
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/driver.py:10, in _create_driver()
#       8 if len(active_drivers) != 1:
#       9     raise RuntimeError(f"{len(active_drivers)} active drivers ({active_drivers}). There should only be one.")
# ---> 10 return active_drivers[0]()
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/backends/nvidia/driver.py:720, in CudaDriver.__init__(self)
#     719 def __init__(self):
# --> 720     self.utils = CudaUtils()  # TODO: make static
#     721     self.launcher_cls = CudaLauncher
#     722     super().__init__()
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/backends/nvidia/driver.py:62, in CudaUtils.__init__(self)
#      61 def __init__(self):
# ---> 62     mod = compile_module_from_src(
#      63         src=Path(os.path.join(dirname, "driver.c")).read_text(),
#      64         name="cuda_utils",
#      65         library_dirs=library_dirs(),
#      66         include_dirs=include_dirs,
#      67         libraries=libraries,
#      68     )
#      69     global PyCUtensorMap
#      70     PyCUtensorMap = mod.PyCUtensorMap
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/build.py:78, in compile_module_from_src(src, name, library_dirs, include_dirs, libraries, ccflags)
#      74 def compile_module_from_src(src: str, name: str, library_dirs: list[str] | None = None,
#      75                             include_dirs: list[str] | None = None, libraries: list[str] | None = None,
#      76                             ccflags: list[str] | None = None) -> ModuleType:
#      77     key = hashlib.sha256((src + platform_key()).encode("utf-8")).hexdigest()
# ---> 78     cache = get_cache_manager(key)
#      79     suffix = sysconfig.get_config_var("EXT_SUFFIX")
#      80     cache_path = cache.get_file(f"{name}{suffix}")
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/cache.py:248, in get_cache_manager(key)
#     246 def get_cache_manager(key) -> CacheManager:
#     247     cls = knobs.cache.manager_class or FileCacheManager
# --> 248     return cls(_base32(key))
#
# File /data/run01/scvi576/envs/sam3/lib/python3.12/site-packages/triton/runtime/cache.py:55, in FileCacheManager.__init__(self, key, override, dump)
#      53     self.cache_dir = os.path.join(self.cache_dir, self.key)
#      54     self.lock_path = os.path.join(self.cache_dir, "lock")
# ---> 55     os.makedirs(self.cache_dir, exist_ok=True)
#      56 else:
#      57     raise RuntimeError("Could not create or locate cache dir")
#
# File <frozen os>:216, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:216, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:230, in makedirs(name, mode, exist_ok)
#
# OSError: [Errno 122] Disk quota exceeded: '/data/home/scvi576/.triton'

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
